# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#3.1-Data-Cleaning" data-toc-modified-id="3.1-Data-Cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>3.1 Data Cleaning</a></span></li><li><span><a href="#3.2-Winsorizing" data-toc-modified-id="3.2-Winsorizing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>3.2 Winsorizing</a></span></li><li><span><a href="#3.3-Merging-the-dataset" data-toc-modified-id="3.3-Merging-the-dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3.3 Merging the dataset</a></span></li><li><span><a href="#4.1-Number-of-Activisms" data-toc-modified-id="4.1-Number-of-Activisms-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>4.1 Number of Activisms</a></span></li><li><span><a href="#4.2-Market-Value-of-Targeted-Firms" data-toc-modified-id="4.2-Market-Value-of-Targeted-Firms-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4.2 Market Value of Targeted Firms</a></span></li><li><span><a href="#4.3-Plot" data-toc-modified-id="4.3-Plot-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>4.3 Plot</a></span></li><li><span><a href="#5.1-Market-Value" data-toc-modified-id="5.1-Market-Value-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>5.1 Market Value</a></span></li><li><span><a href="#5.2-Valuations" data-toc-modified-id="5.2-Valuations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>5.2 Valuations</a></span></li></ul></div>

# %% [markdown]
# # 1. Import Modules

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from scipy import stats
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.mode.chained_assignment = None

# %%
scipy.__version__
# Out:
# '1.0.0'

# %% [markdown]
# # 2. Input Dataset

# %%
#input the data of avtivism
na_values = ['N/A','-99',-99]
HFA = pd.read_csv("HFA 1994-2015.csv",na_values = na_values)

# %%
#input the data of companies
com = pd.read_stata('WRDS_1991-2016.dta')

# %%
#list the columns of companies
com.columns
# Out:
# Index(['amex', 'altman', 'amihudi2', 'analyst', 'assets6', 'b2m', 'b2mquant',
#        'crspage', 'cash1', 'equity216', 'growth3yr', 'hhisic3', 'herfindahl',
#        'inst', 'levb', 'mv', 'mvquant', 'mktshrsic3', 'nyse', 'nasdaq', 'pe',
#        'permno', 'payoutyld', 'q', 'rnd46', 'roa', 'sp500member', 'sales12',
#        'shrpurchase115', 'stkretindadj', 'tdc1', 'to', 'cusip', 'cusip6',
#        'divincrease', 'divyld', 'dnum', 'fyr', 'gvkey', 'newceo', 'yeara'],
#       dtype='object')

# %%
#list the columns of HFA
HFA.columns
# Out:
# Index(['FundName', 'TargetName', 'FundID', 'Permno', 'NCUSIP', 'Gvkey',
#        'EventDate', 'Date13D', 'DateCross5pct'],
#       dtype='object')

# %% [markdown]
# # 3. Preprocess dataset

# %% [markdown]
# ## 3.1 Data Cleaning

# %%
#delete duplicated items
HFA = HFA.drop_duplicates()
com = com.drop_duplicates()

#let the missing data be 0
HFA = HFA.fillna(value = 0)

# %%
#delete the space in the dataset
HFA['Gvkey'] = HFA['Gvkey'].apply(lambda x: str(x).replace(' ',''))
HFA['NCUSIP'] = HFA['NCUSIP'].apply(lambda x: str(x).replace(' ',''))
com['gvkey'] = com['gvkey'].apply(lambda x: str(x).replace(' ','')).astype(int)
com['cusip'] = com['cusip'].apply(lambda x: str(x).replace(' ',''))

# %%
#add 0 for NCUSIP so that NCUSIP can be shown as '*********'
HFA.NCUSIP = HFA['NCUSIP'].apply(lambda x: x.zfill(9))

# %%
#modify the type of gvkey in HFA
HFA['Gvkey'] = HFA['Gvkey'].astype(int)

# %%
#an auxiliary function
#we can use this function to get a new variable -- 'date'
#we define date equal to 'Eventdate' in priority. If 'Eventdate' is missing, we use 'Date13D'.
#If 'Date13D' is missing as well, we use 'Datecross5pct'.
def dat(x):
    if x['EventDate'] == 0:
        if x['Date13D'] == 0:
            return x['DateCross5pct']
        else:
            return x['Date13D']
    else:
        return x['EventDate']
    
#calculate the year of activism
HFA['date'] = HFA[['EventDate','Date13D','DateCross5pct']].apply(dat,axis = 1)
HFA['date'] = pd.to_datetime(HFA['date'].astype(int).astype(str),\
                             errors = 'coerce')

#define a variable 'year' according to variable 'date'
HFA['year'] = [i.year for i in HFA.date]

# %%
#define a new variable equal to year minus 1
HFA = HFA.dropna(subset = ['year'])
HFA['year-1'] = HFA.year - 1

# %%
com['qquant'] = [0]*len(com)
#calculate quantiles for q
for i in range(1994,2016):
    flag = com['yeara'] == i
    q = com[flag].q
    bins = [q.min()-1,q.quantile(0.2),q.quantile(0.4),q.quantile(0.6),q.quantile(0.8),q.max()+1]
    com.loc[com.index[flag],'qquant'] = pd.cut(q,bins,labels = [1,2,3,4,5])

# %% [markdown]
# ## 3.2 Winsorizing

# %%
# make a copy
com1 = com.copy()

# %%
#winsorizing 'mv','cash1','rnd46','q','divyld','growth3yr','roa','b2m' for each year
for col in ['mv','cash1','rnd46','q','divyld','growth3yr','roa','b2m']:
    for year in range(1991,2017):
        a = com1['yeara'] == year
        b = pd.notnull(com1[col])
        com1.loc[com1.index[a & b],col] = \
        stats.mstats.winsorize(com1[a & b][col],limits = (0.01,0.01))

# %%
com1.roa.describe()
# Out:
# count    181422.000000
# mean         -0.146435
# std           1.259098
# min         -24.200000
# 25%          -0.015526
# 50%           0.069866
# 75%           0.148104
# max           0.507573
# Name: roa, dtype: float64

# %%
com1.q.describe()
# Out:
# count    186356.000000
# mean          6.476019
# std          37.110987
# min           0.270816
# 25%           1.076078
# 50%           1.569370
# 75%           2.936518
# max        1076.634783
# Name: q, dtype: float64

# %% [markdown]
# ## 3.3 Merging the dataset

# %%
gv = HFA['Gvkey'] != 0
perm = HFA['Permno'] != 0
cus = HFA['NCUSIP'] != '000000000'

#merge the data through gvkey and year-1
data1 = HFA[gv]
data1 = pd.merge(data1,com1,left_on = ['Gvkey','year-1'],\
                 right_on = ['gvkey','yeara'])

#merge the data through permno and year-1
data2 = HFA[perm]
data2 = pd.merge(data2,com1,left_on = ['Permno','year-1'],\
                 right_on = ['permno','yeara'])

#merge the data through NCUSIP and year-1
data3 = HFA[cus]
data3 = pd.merge(HFA,com1,left_on = ['NCUSIP','year-1'],\
                 right_on = ['cusip','yeara'])

# %%
# add1 = data2[data2.Gvkey == 0]
# flag1 = data3.Gvkey == 0
# flag2 = data3.Permno == 0
# add2 = data3[flag1 & flag2]

# %%
# data = pd.concat([data1,add1,add2],ignore_index = True)

# %%
com1.dnum
# Out:
# 0         5080
# 1         3460
# 2         4841
# 3         3661
# 4         6512
# 5         3812
# 6         3844
# 7         2834
# 8         3443
# 9         7830
# 10        5040
# 11        4512
# 12        3564
# 13        7373
# 14        3571
# 15        3825
# 16        3089
# 17        6799
# 18        7373
# 19        4911
# 20        7359
# 21        2834
# 22        8700
# 23        4955
# 24        5160
# 25        4833
# 26        6351
# 27        3661
# 28        3612
# 29        3420
#           ...
# 214610    6020
# 214611    3845
# 214612    2836
# 214613    2836
# 214614    2860
# 214615    2911
# 214616    2836
# 214617    7370
# 214618    2834
# 214619    2820
# 214620    3523
# 214621    1381
# 214622    4512
# 214623    2836
# 214624    1381
# 214625    1381
# 214626    4512
# 214627    3577
# 214628    3841
# 214629
# 214630    8200
# 214631    2890
# 214632
# 214633    2836
# 214634    4412
# 214635    3420
# 214636    4412
# 214637
# 214638
# 214639
# Name: dnum, Length: 214640, dtype: object

# %%
HFA
# Out:
#                                   FundName  \
# 0         ACCIPITER CAPITAL MANAGEMENT LLC
# 1         ACCIPITER CAPITAL MANAGEMENT LLC
# 2         ACCIPITER CAPITAL MANAGEMENT LLC
# 3         ACCIPITER CAPITAL MANAGEMENT LLC
# 4         ACCIPITER CAPITAL MANAGEMENT LLC
# 5         ACCIPITER CAPITAL MANAGEMENT LLC
# 6         ACCIPITER CAPITAL MANAGEMENT LLC
# 7         ACCIPITER CAPITAL MANAGEMENT LLC
# 8                  ACQUISITOR HOLDINGS LTD
# 9                  ACQUISITOR HOLDINGS LTD
# 10                 ACQUISITOR HOLDINGS LTD
# 11                 ACQUISITOR HOLDINGS LTD
# 12                          ACQUISITOR PLC
# 13                          ACQUISITOR PLC
# 14                          ACQUISITOR PLC
# 15                          ACQUISITOR PLC
# 16            ANDREEFF EQUITY ADVISORS LLC
# 17            ANDREEFF EQUITY ADVISORS LLC
# 18      ATLANTIC INVESTMENT MANAGEMENT INC
# 19      ATLANTIC INVESTMENT MANAGEMENT INC
# 20      ATLANTIC INVESTMENT MANAGEMENT INC
# 21      ATLANTIC INVESTMENT MANAGEMENT INC
# 22      ATLANTIC INVESTMENT MANAGEMENT INC
# 23      ATLANTIC INVESTMENT MANAGEMENT INC
# 24      ATLANTIC INVESTMENT MANAGEMENT INC
# 25      ATLANTIC INVESTMENT MANAGEMENT INC
# 26      ATLANTIC INVESTMENT MANAGEMENT INC
# 27      ATLANTIC INVESTMENT MANAGEMENT INC
# 28      ATLANTIC INVESTMENT MANAGEMENT INC
# 29      ATLANTIC INVESTMENT MANAGEMENT INC
# ...                                    ...
# 4264                      CASTLE UNION LLC
# 4265                    CLOVER PARTNERS LP
# 4266                       EJF CAPITAL LLC
# 4267             FIREFLY VALUE PARTNERS LP
# 4268                      MUTINY FUND I LP
# 4269                      JVL ADVISORS LLC
# 4270                 KYNIKOS ASSOCIATES LP
# 4271       LANSDOWNE PARTNERS AUSTRIA GMBH
# 4272                        LUCUS ADVISORS
# 4273       MACELLUM CAPITAL MANAGEMENT LLC
# 4274                  MAKAIRA PARTNERS LLC
# 4275       MOUNT FLAG MEDIA INVESTMENT LLC
# 4276  NORTHERN RIGHT CAPITAL MANAGEMENT LP
# 4277  NORTHERN RIGHT CAPITAL MANAGEMENT LP
# 4278                   PELHAM CAPITAL LTD.
# 4279            PLEASANT LAKE PARTNERS LLC
# 4280        RDG CAPITAL FUND MANAGEMENT LP
# 4281        RDG CAPITAL FUND MANAGEMENT LP
# 4282           TIBURON OPPORTUNITY FUND LP
# 4283           VENOR CAPITAL MANAGEMENT LP
# 4284                    VETERI PLACE CORP.
# 4285                    VETERI PLACE CORP.
# 4286                    VETERI PLACE CORP.
# 4287                    VETERI PLACE CORP.
# 4288                    VETERI PLACE CORP.
# 4289            VIEX CAPITAL ADVISORS, LLC
# 4290            VIEX CAPITAL ADVISORS, LLC
# 4291            VIEX CAPITAL ADVISORS, LLC
# 4292            VIEX CAPITAL ADVISORS, LLC
# 4293        WOLVERINE ASSET MANAGEMENT LLC
#
#                                TargetName  FundID   Permno     NCUSIP   Gvkey  \
# 0                   ARENA PHARMACEUTICALS       1  88421.0  004004710  138122
# 1                LIFEPOINT HOSPITALS INC.       1  86899.0  053219L10  120297
# 2                AMERICAN HOMEPATIENT INC       1  77098.0  002664910   24668
# 3                 RURAL/METRO CORPORATION       1  79417.0  078174810   28616
# 4                         VISTACARE, INC.       1  89622.0  092839Y10  150284
# 5              PENWEST PHARMACEUTICALS CO       1  86333.0  070975410  113533
# 6                     ORCHID CELLMARK INC       1  88255.0  068573C10  135004
# 7                TRIPLE S MANAGEMENT CORP       1  92506.0  896749108  174647
# 8                        AIR METHODS CORP       2  11641.0  000912830   13789
# 9                              ALDILA INC       2  79247.0  001438420   28388
# 10                MERCURY AIR GROUP, INC.       2  64004.0  058935410    5847
# 11           BAKER (MICHAEL), CORPORATION       2  52484.0  005714910    1974
# 12            MILLER BUILDING SYSTEMS INC       3  10307.0  060040410   12214
# 13                  DATRON SYSTEMS INC/DE       3  12005.0  023817310    3796
# 14                  CATALINA LIGHTING INC       3  75286.0  014886510   14457
# 15                   COLORADO MEDTECH INC       3  28063.0  019652U10    3673
# 16                      BACK YARD BURGERS       4  79252.0  005635W10   28501
# 17                       GEOKINETICS INC.       4  38790.0  037291020   12708
# 18                   C&D TECHNOLOGIES INC       5  71685.0  012466110   13328
# 19            JLK DIRECT DISTRIBUTION INC       5  85065.0  046621C10   64999
# 20                     HARSCO CORPORATION       5  25304.0  041586410    5496
# 21                  DOLE FOOD COMPANY INC       5  40707.0  025660510    2812
# 22        PRECISION CASTPARTS CORPORATION       5  63830.0  074018910    8717
# 23                        SPX CORPORATION       5  55212.0  078463510    5087
# 24                     DEL MONTE FOODS CO       5  86590.0  024522P10   24283
# 25                SONOCO PRODUCTS COMPANY       5  71176.0  083549510    9815
# 26           BLACK AND DECKER CORPORATION       5  20220.0  009179710    2255
# 27          R.R. DONNELLEY & SONS COMPANY       5  38682.0  025786710    4040
# 28                             JOY GLOBAL       5  89105.0  048116510   13003
# 29                 RR DONNELLEY & SONS CO       5  38682.0  025786710    4040
# ...                                   ...     ...      ...        ...     ...
# 4264               PROCERA NETWORKS, INC.     898  92282.0  74269U203  158791
# 4265         FINANCIAL INSTITUTIONS, INC.     899  86965.0  317585404  121713
# 4266            ALEXANDER & BALDWIN, INC.     901  13429.0  014491104   11756
# 4267                    ASB BANCORP, INC.     902  13036.0  00213T109  190567
# 4268         NORTECH SYSTEMS INCORPORATED     903  79322.0  656553104    3962
# 4269                   JONES ENERGY, INC.     904  14026.0  48019R108   18109
# 4270                      SOLARCITY CORP.     905  13711.0  83416T100   15314
# 4271         ALEXZA PHARMACEUTICALS, INC.     906  91154.0  015384209  166414
# 4272    CAPITAL SENIOR LIVING CORPORATION     908  85419.0  140475104   65732
# 4273      CHRISTOPHER & BANKS CORPORATION     909  77478.0  171046105   25108
# 4274         WESCO AIRCRAFT HOLDINGS, INC     910  12908.0  950814103  187714
# 4275               TRIBUNE PUBLISHING CO.     912  14781.0  89703P107   19578
# 4276      TELECOMMUNICATION SYSTEMS, INC.     913  88574.0  87929J103  138613
# 4277                    PRGX GLOBAL, INC.     913  83304.0  69357C503   62494
# 4278                        GRUBHUB, INC.     914  14567.0  400110102   19906
# 4279  MAGNACHIP SEMICONDUCTOR CORPORATION     915  12629.0  55933J203  233491
# 4280         TRAVELCENTERS OF AMERICA LLC     917  91727.0  894174101  148350
# 4281                 INTERNAP CORPORATION     917  87236.0  45885A300  124358
# 4282     CACHET FINANCIAL SOLUTIONS, INC.     920  28513.0  12718M109    6941
# 4283            WESTMORELAND COAL COMPANY     921  59467.0  960878106   11440
# 4284             SI FINANCIAL GROUP, INC.     922  90421.0  78425V104  160667
# 4285                       SUSSEX BANCORP     922  85798.0  869245100   65884
# 4286                    ASB BANCORP, INC.     922  13036.0  00213T109  190567
# 4287               WESTBURY BANCORP, INC.     922  13885.0  95727P106   17707
# 4288                  MSB FINANCIAL CORP.     922  91741.0  55352P102  176350
# 4289                 GSI TECHNOLOGY, INC.     923  91901.0  36241U106  160213
# 4290                  MERU NETWORKS, INC.     923  93307.0  59047Q103  184057
# 4291                         NUMEREX CORP     923  82541.0  67053A102   30029
# 4292  ELECTRO SCIENTIFIC INDUSTRIES, INC.     923  32054.0  285229100    4274
# 4293             BARFRESH FOOD GROUP INC.     924  76996.0  067532101   24462
#
#        EventDate     Date13D  DateCross5pct       date    year  year-1
# 0     20050131.0  20050131.0            0.0 2005-01-31  2005.0  2004.0
# 1     20060324.0         0.0            0.0 2006-03-24  2006.0  2005.0
# 2     20060616.0  20060616.0     20060615.0 2006-06-16  2006.0  2005.0
# 3     20060905.0  20060905.0     20060824.0 2006-09-05  2006.0  2005.0
# 4     20080207.0  20080207.0     20080206.0 2008-02-07  2008.0  2007.0
# 5     20080219.0  20080219.0     20080215.0 2008-02-19  2008.0  2007.0
# 6     20100310.0  20100310.0     20100308.0 2010-03-10  2010.0  2009.0
# 7     20130528.0  20130528.0     20130517.0 2013-05-28  2013.0  2012.0
# 8     20021009.0  20021009.0     20021007.0 2002-10-09  2002.0  2001.0
# 9     20021009.0  20021009.0     20021007.0 2002-10-09  2002.0  2001.0
# 10    20021202.0  20021202.0     20021122.0 2002-12-02  2002.0  2001.0
# 11    20030527.0  20030527.0     20030514.0 2003-05-27  2003.0  2002.0
# 12    20000712.0  20000712.0     20000706.0 2000-07-12  2000.0  1999.0
# 13    20001115.0  20001115.0     20001109.0 2000-11-15  2000.0  1999.0
# 14    20001229.0  20001229.0     20001219.0 2000-12-29  2000.0  1999.0
# 15    20010209.0  20010209.0     20010201.0 2001-02-09  2001.0  2000.0
# 16    20051107.0  20051107.0     20050822.0 2005-11-07  2005.0  2004.0
# 17    20060119.0  20060119.0     20051201.0 2006-01-19  2006.0  2005.0
# 18    19980604.0  19980604.0     19980529.0 1998-06-04  1998.0  1997.0
# 19    19981120.0  19981120.0     19981118.0 1998-11-20  1998.0  1997.0
# 20    20011217.0  20011217.0     20011213.0 2001-12-17  2001.0  2000.0
# 21    20020731.0  20020731.0     20020731.0 2002-07-31  2002.0  2001.0
# 22    20021010.0  20021010.0     20021002.0 2002-10-10  2002.0  2001.0
# 23    20040805.0  20040805.0     20040802.0 2004-08-05  2004.0  2003.0
# 24    20040914.0  20040914.0     20040913.0 2004-09-14  2004.0  2003.0
# 25    20050818.0  20050818.0     20050812.0 2005-08-18  2005.0  2004.0
# 26    20051014.0  20051014.0     20051013.0 2005-10-14  2005.0  2004.0
# 27    20060127.0  20060127.0     20060127.0 2006-01-27  2006.0  2005.0
# 28    20070322.0  20070322.0     20070321.0 2007-03-22  2007.0  2006.0
# 29    20080225.0  20080225.0     20080213.0 2008-02-25  2008.0  2007.0
# ...          ...         ...            ...        ...     ...     ...
# 4264  20141028.0  20141028.0     20141024.0 2014-10-28  2014.0  2013.0
# 4265  20151216.0  20151216.0     20151216.0 2015-12-16  2015.0  2014.0
# 4266  20150911.0  20150911.0     20150904.0 2015-09-11  2015.0  2014.0
# 4267  20150803.0  20150803.0     20111114.0 2015-08-03  2015.0  2014.0
# 4268  20150624.0  20150624.0     20150624.0 2015-06-24  2015.0  2014.0
# 4269  20150217.0  20150217.0     20140131.0 2015-02-17  2015.0  2014.0
# 4270  20150821.0         0.0            0.0 2015-08-21  2015.0  2014.0
# 4271  20150803.0  20150803.0     20121231.0 2015-08-03  2015.0  2014.0
# 4272  20151009.0  20151009.0     20151001.0 2015-10-09  2015.0  2014.0
# 4273  20150401.0  20150401.0     20150327.0 2015-04-01  2015.0  2014.0
# 4274  20150223.0  20150227.0     20141231.0 2015-02-23  2015.0  2014.0
# 4275  20151002.0  20151002.0     20150928.0 2015-10-02  2015.0  2014.0
# 4276  20141113.0  20141124.0     20141113.0 2014-11-13  2014.0  2013.0
# 4277  20150420.0  20150420.0     20150408.0 2015-04-20  2015.0  2014.0
# 4278  20151006.0  20151006.0            0.0 2015-10-06  2015.0  2014.0
# 4279  20150610.0  20150610.0            0.0 2015-06-10  2015.0  2014.0
# 4280  20150224.0         0.0            0.0 2015-02-24  2015.0  2014.0
# 4281  20150427.0         0.0            0.0 2015-04-27  2015.0  2014.0
# 4282  20150825.0  20150825.0     20150410.0 2015-08-25  2015.0  2014.0
# 4283  20151030.0  20151030.0     20150721.0 2015-10-30  2015.0  2014.0
# 4284  20110629.0  20110629.0     20110621.0 2011-06-29  2011.0  2010.0
# 4285  20150302.0  20150302.0     20150220.0 2015-03-02  2015.0  2014.0
# 4286  20150401.0  20150401.0     20150323.0 2015-04-01  2015.0  2014.0
# 4287  20150511.0  20150511.0     20150501.0 2015-05-11  2015.0  2014.0
# 4288  20150722.0  20150724.0     20150717.0 2015-07-22  2015.0  2014.0
# 4289  20150114.0  20150114.0     20150113.0 2015-01-14  2015.0  2014.0
# 4290  20150304.0         0.0            0.0 2015-03-04  2015.0  2014.0
# 4291  20150611.0  20150611.0     20150603.0 2015-06-11  2015.0  2014.0
# 4292  20150625.0  20150625.0     20150618.0 2015-06-25  2015.0  2014.0
# 4293  20150323.0  20150323.0     20150313.0 2015-03-23  2015.0  2014.0
#
# [4278 rows x 12 columns]

# %%
HFA.to_csv("HFA.csv",encoding='utf-8')
# com1.to_csv("companies_cleaned.csv")

# %%
data2.to_csv('Merge.csv',encoding='utf-8')

# %%
com1.to_csv('Company.csv',encoding='utf-8')

# %%
tar_count = pd.pivot_table(data2[data2.mvquant > 4],index='year',columns='gvkey',values='FundID',aggfunc=np.count_nonzero)

# %%
hfa_count = tar_count.apply(lambda x: np.mean(x[pd.notnull(x)]),axis=1)
print(np.mean(hfa_count[hfa_count.index<2011]))
print(np.mean(hfa_count[hfa_count.index>2009]))
# Out:
# 1.040515779197702
# 1.1076087646087067

# %%
hfa_count[1994:2015].plot()

# %% [markdown]
# # 4. Incidence of Activisms

# %% [markdown]
# ## 4.1 Number of Activisms

# %%
#calculate the number of activisms each year
activisms = HFA[pd.notnull(HFA['year'])]['year'].value_counts()
activisms = activisms.sort_index()
activists = HFA.drop_duplicates(['year','FundID'])
activists = activists['year'].value_counts()
activists = activists.sort_index()
num_com = com1['yeara'].value_counts()
num_com = num_com.sort_index()

# %%
tar_firm = HFA.drop_duplicates(['year','Permno'])
tar_firm = tar_firm['year'].value_counts()
incidence = tar_firm/num_com

# %% [markdown]
# ## 4.2 Market Value of Targeted Firms

# %%
MV = pd.pivot_table(data2,values = 'mv',index = 'year',aggfunc = np.sum)

# %%
print(MV)
# Out:
#                   mv
# year
# 1994.0  6.016375e+03
# 1995.0  6.678964e+03
# 1996.0  2.366557e+04
# 1997.0  5.797490e+04
# 1998.0  3.500588e+04
# 1999.0  3.472305e+04
# 2000.0  4.777141e+04
# 2001.0  3.292327e+04
# 2002.0  6.221445e+04
# 2003.0  4.097734e+04
# 2004.0  2.151769e+05
# 2005.0  3.348872e+05
# 2006.0  4.476315e+05
# 2007.0  5.842890e+05
# 2008.0  3.788997e+05
# 2009.0  1.038680e+05
# 2010.0  2.234583e+05
# 2011.0  3.942954e+05
# 2012.0  3.689622e+05
# 2013.0  7.395372e+05
# 2014.0  1.011594e+06
# 2015.0  9.973818e+05
# 2016.0  1.303332e+04

# %% [markdown]
# ## 4.3 Plot

# %%
sns.set(style='darkgrid')
fig1, ax = plt.subplots(2,1,sharex = True,figsize = (15,10),dpi = 100)

ax[0].plot(activisms.loc[1994:2015],linestyle = '-',lw = 3,color = 'red',\
           marker = 'o',markerfacecolor = 'green',markeredgecolor = 'green')
ax[0].set_xlim([1993,2016])
ax[0].set_xticks([1995,2000,2005,2010,2015])
ax[0].set_yticks(list(range(0,500,100)))
ax[0].set_yticklabels(list(range(0,500,100)),fontsize = 13)
ax[0].set_title('Number of Activists',fontsize = 20)

ax[1].plot(MV[1994:2015],linestyle = '-',lw = 3,color = 'blue',marker = '^',\
           markerfacecolor = 'red',markeredgecolor = 'red')
ax[1].set_title('Scale of Activists',fontsize = 20,loc = 'center')
ax[1].set_xticklabels([1995,2000,2005,2010,2015],fontsize = 13)
ax[1].set_yticks(list(range(0,1500000,250000)))
ax[1].set_yticklabels(list(range(0,1500,250)),fontsize = 13)
ax[1].set_ylabel('(billion)',rotation=0,horizontalalignment = 'right',\
                 verticalalignment = 'bottom',fontsize = 15)

plt.subplots_adjust(hspace = 0.12)

# %%
fig2 = plt.figure(figsize = (15,6),dpi = 200)

ax1 = fig2.add_subplot(111)
# MV.columns = ["market value(left)"]
ax1.bar(np.arange(1994,2016),MV[1994:2015]['mv'],alpha = 0.7,color='orangered',label = "market value(left)")
ax1.set_xlim([1993,2016])
ax1.set_xticks([1995,2000,2005,2010,2015])
ax1.set_xticklabels([1995,2000,2005,2010,2015],fontsize = 18,rotation = 0)
ax1.set_ylim([0,1125000])
ax1.set_yticks(list(range(0,1250000,250000)))
ax1.set_yticklabels(list(range(0,1250,250)),fontsize = 18)
ax1.set_ylabel('Total market value',weight='bold',fontsize = 20)
ax1.set_label("market value(left)")
ax1.legend(loc = (0.01,0.9),fontsize = 18)
ax1.text(1991.45,1080000,'(billions)',fontsize=18,style='italic')

ax2 = ax1.twinx()

ax2.plot(activisms[1994:2015],linestyle = '-',lw = 3,color = 'royalblue',\
        marker = 'o',markersize=10,\
         label = 'number of activism attacks(right)')
ax2.set_ylim([0,450])
ax2.set_yticks([0,100,200,300,400])
ax2.set_yticklabels([0,100,200,300,400],fontsize = 18)

# ax2.set_title("Number and Scale of Activist 'attack'",fontsize = 30)
ax2.grid(False)

ax2.plot(activists[1994:2015],linestyle = '--'
         ,lw = 3,color = 'green',markersize=10,
        marker = 'o',markerfacecolor = 'green',markeredgecolor = 'green',\
         label = 'number of activists(right)')
ax2.tick_params(axis='both',direction='out',length=5,which='both')
ax1.tick_params(axis='both',direction='out',length=5,which='both')
ax2.set_ylabel("Total number",weight='bold',fontsize=20)
ax2.legend(loc = (0.01,0.74),fontsize = 18)
plt.savefig('total.png',dpi=200,bbox_inches='tight')

# %%
# ?plt.savefig

# %%
fig3 = plt.figure(figsize = (15,5))
ax = fig3.add_subplot(111)
ax.plot(incidence[1994:2015],lw = 3,marker = 'o')
ax.set_xticks([1995,2000,2005,2010,2015])
# ax.set_title("The incidence of hedge fund activism",\
#              fontsize = 25)
# Out:
# [<matplotlib.axis.XTick at 0x1d02ece5908>,
#  <matplotlib.axis.XTick at 0x1d02f2a1f60>,
#  <matplotlib.axis.XTick at 0x1d02a5d0390>,
#  <matplotlib.axis.XTick at 0x1d02f2c2978>,
#  <matplotlib.axis.XTick at 0x1d02f2c5128>]

# %% [markdown]
# # 5. Characteristics of Targeted Firms

# %% [markdown]
# ## 5.1 Market Value

# %%
# plt.style.use('ggplot')
# fig4 = plt.figure(figsize = (8,6),dpi = 100)
dist1 = data2['mvquant'].value_counts()
dist1 = dist1.sort_index()
dist1.index = ['Q1','Q2','Q3','Q4','Q5']
# dist1.plot(kind = 'bar',color = 'brown',\
#            title = "The distribution of targeted firms' market value")

# %%
dist1_ts = pd.pivot_table(data2,index = 'year',columns = 'mvquant',\
                          values = 'gvkey',\
                          aggfunc = np.count_nonzero)[1994:2015]
total = dist1_ts.sum(axis = 1)
dist1_ts_pct = dist1_ts.apply(lambda x: x/total)
dist1_ts_pct.columns = ['Q1','Q2','Q3','Q4','Q5']

# %%
dist1_tpct = dist1_ts_pct.apply(np.mean,axis = 0)
w = 0.2
x = np.arange(1,6)
fig10 = plt.figure(figsize = (8,6),dpi = 100)
ax1 = fig10.add_subplot(111)
ax1.bar(x,dist1_tpct,width=w,label='Market Capitalization')
ax1.bar(x+0.2,dist2_tpct,width=w,label='B2M')
ax1.bar(x-0.2,dist3_tpct,width=w,label="Tobin's q")

#            title = "The distribution of targeted firms' market value")
# Out:
# <Container object of 5 artists>

# %%
fig10 = plt.figure(figsize = (12,6.3),dpi = 200)
# cs=cm.Set1(np.arange(40)/40.)
ax1 = fig10.add_subplot(121)
explode = [0.02]*5
ax1.pie(dist1_tpct,explode=explode, autopct='%1.1f%%',colors=plt.cm.Blues(range(1,251,50)))
ax1.text(-0.65,-1.13,'Market Capitalization',weight='bold',size=18)
ax2 = fig10.add_subplot(122)
ax2.pie(dist2_tpct,explode=explode, autopct='%1.1f%%',colors=plt.cm.Blues(range(1,251,50)))
ax2.text(-0.65,-1.13,'Book-to-Market Ratio',weight='bold',size=18)
ax1.legend(['Q1','Q2','Q3','Q4','Q5'],
           fontsize=16,frameon=True,ncol=5,bbox_to_anchor=(1.75,0.03))
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig('distribution.png',dpi=200,bbox_inches='tight')

# %%
plt.cm.Reds(range(1,6))
# Out:
# array([[0.99987697, 0.95820069, 0.93748558, 1.        ],
#        [0.99975394, 0.95561707, 0.93379469, 1.        ],
#        [0.99963091, 0.95303345, 0.93010381, 1.        ],
#        [0.99950788, 0.95044983, 0.92641292, 1.        ],
#        [0.99938485, 0.94786621, 0.92272203, 1.        ]])

# %%
# plt.style.use('ggplot')
fig5 = plt.figure(figsize = (15,5))
ax = fig5.add_subplot(111)
ax.plot(dist1_ts_pct,lw = 3,marker = 'o')
ax.set_xticks([1995,2000,2005,2010,2015])
ax.legend(dist1_ts_pct.columns,loc = 'best')
# ax.set_title("The change of percentage of tageted firms in different size",\
#              fontsize = 25)

# %%
df1 = pd.DataFrame({'total_mv_median':[0]*22,'tar_mv_median':[0]*22},\
                   index = list(range(1993,2015)))

for year in range(1993,2015):
    df1.loc[year,'total_mv_median'] = com1[com1['yeara'] == year].mv.median()
    df1.loc[year,'tar_mv_median'] = data2[data2['yeara'] == year].mv.median()

df1['diff'] = df1['tar_mv_median'] - df1['total_mv_median']

# %%
fig15 = plt.figure(figsize = (15,6),dpi = 100)
ax = fig15.add_subplot(111)
ax.plot(df1['total_mv_median'],lw = 3,marker = 'o',markersize=8,label = 'median of all companies(left)')
ax.plot(df1['tar_mv_median'],lw = 3,marker = 'o',markersize=8,label = 'median of targets(left)')
ax.legend(loc = (0.01,0.86),fontsize = 12)
ax.set_ylabel('(million)',rotation=0,horizontalalignment = 'right',\
               verticalalignment = 'bottom',fontsize = 10)

ax2 = ax.twinx()
ax2.bar(np.arange(1993,2015),df1['diff'],alpha = 0.3,hatch = '////',color = 'yellow',\
        label = 'difference between population and targets(right)')
ax2.legend(loc = (0.01,0.8),fontsize = 12)
ax2.grid(False)
ax2.set_ylim([-300,400])
ax2.set_yticks([-200,0,200,400])
# Out:
# [<matplotlib.axis.YTick at 0x1d02fa71828>,
#  <matplotlib.axis.YTick at 0x1d02fb35e80>,
#  <matplotlib.axis.YTick at 0x1d02f6d74e0>,
#  <matplotlib.axis.YTick at 0x1d02f6c2128>]

# %% [markdown]
# ## 5.2 Valuations

# %%
# fig6 = plt.figure(figsize = (8,6),dpi = 100)
dist2 = data2['b2mquant'].value_counts()
dist2 = dist2.sort_index()
dist2.index = ['Q1','Q2','Q3','Q4','Q5']
# dist2.plot(kind = 'bar',color = 'gold',\
#            title = "The distribution of targeted firms' book-to-market ratio")

# %%
dist2_ts = pd.pivot_table(data2,index = 'year',columns = 'b2mquant',\
                          values = 'gvkey',\
                          aggfunc = np.count_nonzero)[1995:2015]
total = dist2_ts.sum(axis = 1)
dist2_ts_pct = dist2_ts.apply(lambda x: x/total)
dist2_ts_pct.columns = ['Q1','Q2','Q3','Q4','Q5']

# %%
dist2_tpct = dist2_ts_pct.apply(np.mean,axis = 0)

# %%
fig7 = plt.figure(figsize = (15,5))
ax = fig7.add_subplot(111)
ax.plot(dist2_ts_pct,lw = 3,marker = 'o')
ax.set_xticks([1995,2000,2005,2010,2015])
ax.legend(dist2_ts_pct.columns,loc = 'best')
# ax.set_title("The percentage of tageted \
# firms with different book-to-market ratio",fontsize = 25)

# %%
df2 = pd.DataFrame({'total_b2m_median':[0]*22,'tar_b2m_median':[0]*22},\
                   index = list(range(1993,2015)))

for year in range(1993,2015):
    df2.loc[year,'total_b2m_median'] = com1[com1['yeara'] == year].b2m.median()
    df2.loc[year,'tar_b2m_median'] = data2[data2['yeara'] == year].b2m.median()

df2['diff'] = df2['tar_b2m_median'] - df2['total_b2m_median']

# %%
sns.set(style='dark')
fig16 = plt.figure(figsize = (10,8),dpi = 200)

ax2 = fig16.add_subplot(211)
ax2.bar(np.arange(1993,2015),df1['diff'],alpha = 0.5,color = 'orangered',\
        label = 'difference between population and targets(right)')
ax2.legend(loc = (0.01,0.71),fontsize = 12)
ax2.set_ylim([-300,400])
ax2.set_yticks([-200,0,200,400])
ax2.set_title('Market Capitalization',size=15,weight='bold')

ax1 = ax2.twinx()

ax1.plot(df1['total_mv_median'],lw = 1.5,marker = 'o',
         label = 'median of all companies(left)',color='royalblue')
ax1.plot(df1['tar_mv_median'],lw = 1.5,marker = 'o',
         label = 'median of targets(left)',color='green')
ax1.legend(loc = (0.01,0.8),fontsize = 12)
ax1.text(2015,520,'(millions)',fontsize=10,style='italic')
ax2.tick_params(axis='both',direction='out',length=3,which='both')
ax1.tick_params(axis='both',direction='out',length=3,which='both')
plt.subplots_adjust(hspace=0.2)


ax4 = fig16.add_subplot(212)
ax4.bar(np.arange(1993,2015),df2['diff'],alpha = 0.5,color = 'orangered',\
       label = 'difference between population and targets(right)')
ax4.legend(loc = 'best',fontsize = 12)
ax4.set_ylim([-0.6,1])
ax4.set_yticks([-0.5,0,0.5,1])
ax4.set_title('B2M',size=15,weight='bold')

ax3 = ax4.twinx()
ax3.plot(df2['total_b2m_median'],lw = 1.5,marker = 'o',
         label = "median of all companies(left)",color='royalblue')
ax3.plot(df2['tar_b2m_median'],lw = 1.5,marker = 'o',
         label = 'median of targets(left)',color='green')
ax3.legend(loc = (0.01,0.8),fontsize = 12)
ax3.tick_params(axis='both',direction='out',length=3,which='both')
ax4.tick_params(axis='both',direction='out',length=3,which='both')
plt.savefig('median.png',dpi=200,bbox_inches='tight')

# %%
# fig8 = plt.figure(figsize = (8,6),dpi = 100)
sub = data2[data2['qquant'].isin([1,2,3,4,5])]
dist3 = sub['qquant'].value_counts()
dist3 = dist3.sort_index()
dist3.index = ['Q1','Q2','Q3','Q4','Q5']
# dist3.plot(kind = 'bar',color = 'green',\
#            title = "The distribution of targeted firms' q")

# %%
dist3_ts = pd.pivot_table(sub,index = 'year',columns = 'qquant',\
                          values = 'gvkey',\
                          aggfunc = np.count_nonzero)[1995:2015]
total = dist3_ts.sum(axis = 1)
dist3_ts_pct = dist3_ts.apply(lambda x: x/total)
dist3_ts_pct.columns = ['Q1','Q2','Q3','Q4','Q5']

# %%
dist3_tpct = dist3_ts_pct.apply(np.mean,axis = 0)
fig12 = plt.figure(figsize = (8,6),dpi = 100)
dist3_tpct.plot(kind = 'bar',color = 'green')
#            title = "The distribution of targeted firms' q")

# %%
fig9 = plt.figure(figsize = (15,5))
ax = fig9.add_subplot(111)
ax.plot(dist3_ts_pct,lw = 3,marker = 'o')
ax.set_xticks([1995,2000,2005,2010,2015])
ax.legend(dist3_ts_pct.columns,loc = 'best')
# ax.set_title("The percentage of tageted \
# firms with different q",fontsize = 25)

# %%
df3 = pd.DataFrame({'total_q_median':[0]*22,'tar_q_median':[0]*22},\
                   index = list(range(1993,2015)))

for year in range(1993,2015):
    df3.loc[year,'total_q_median'] = com1[com1['yeara'] == year].q.median()
    df3.loc[year,'tar_q_median'] = data2[data2['yeara'] == year].q.median()

df3['diff'] = df3['tar_q_median'] - df3['total_q_median']

# %%
fig17 = plt.figure(figsize = (15,6),dpi = 100)
ax = fig17.add_subplot(111)
ax.plot(df3['total_q_median'],lw = 3,marker = 'o',label = 'median of all companies(left)')
ax.plot(df3['tar_q_median'],lw = 3,marker = 'o',label = 'median of targets(left)')
ax.legend(loc = (0.01,0.86),fontsize = 12)
ax.set_ylim([0.9,2.1])

ax2 = ax.twinx()
ax2.bar(np.arange(1993,2015),df3['diff'],alpha = 0.3,hatch = '////',color = 'yellow',\
       label = 'difference between population and targets(right)')
ax2.legend(loc = 'best',fontsize = 12)
ax2.grid(False)
ax2.set_ylim([-1.2,1.2])
# Out:
# (-1.2, 1.2)
